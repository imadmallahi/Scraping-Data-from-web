# %%
from facebook_scraper import get_posts
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import WordPunctTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

#RegexpTokensizer class : A RegexplTokenizer
from nltk.tokenize import RegexpTokenizer

stemmer = PorterStemmer()

for post in get_posts('hespress', pages=20):
    print(post['text'])
    tokenizer = RegexpTokenizer(r'\w+')#remove also puntion
    token  = tokenizer.tokenize(post['text'])
    print("\n-------------- Tokenzer :\n :", token )
    stopwords_en = stopwords.words('arabic')
    tokens_clean = [t for t in token if  t not in stopwords_en]
    print("\n ------------ stop word removal : tokens_clean \n",tokens_clean)
    #Stemming using PorterStemmer()
    stems =[stemmer.stem(t) for t in tokens_clean]
    print("\n ------------ Stemming : stem  \n",stems)

    print('=================================')
# Out:
# وزير العدل محمد بنعبد القادر يكشف أن الملك محمد السادس قرر إصدار العفو على الصحفية هاجر الريسوني وخطيبها رفعت الأمين بعدما حكمت المحكمة الابتدائية بالرباط عليها بسنة حبسا نافذا وغرامة مالية قدرها 500 درهم، وقضت في حق خطيبها، الأكاديمي والناشط الحقوقي السوداني، بالحكم ذاته.
# التفاصيل: http://bit.ly/2oMtI1V
#
# -------------- Tokenzer :
#  : ['وزير', 'العدل', 'محمد', 'بنعبد', 'القادر', 'يكشف', 'أن', 'الملك', 'محمد', 'السادس', 'قرر', 'إصدار', 'العفو', 'على', 'الصحفية', 'هاجر', 'الريسوني', 'وخطيبها', 'رفعت', 'الأمين', 'بعدما', 'حكمت', 'المحكمة', 'الابتدائية', 'بالرباط', 'عليها', 'بسنة', 'حبسا', 'نافذا', 'وغرامة', 'مالية', 'قدرها', '500', 'درهم', 'وقضت', 'في', 'حق', 'خطيبها', 'الأكاديمي', 'والناشط', 'الحقوقي', 'السوداني', 'بالحكم', 'ذاته', 'التفاصيل', 'http', 'bit', 'ly', '2oMtI1V']
#
#  ------------ stop word removal : tokens_clean
#  ['وزير', 'العدل', 'محمد', 'بنعبد', 'القادر', 'يكشف', 'الملك', 'محمد', 'السادس', 'قرر', 'إصدار', 'العفو', 'الصحفية', 'هاجر', 'الريسوني', 'وخطيبها', 'رفعت', 'الأمين', 'بعدما', 'حكمت', 'المحكمة', 'الابتدائية', 'بالرباط', 'عليها', 'بسنة', 'حبسا', 'نافذا', 'وغرامة', 'مالية', 'قدرها', '500', 'درهم', 'وقضت', 'حق', 'خطيبها', 'الأكاديمي', 'والناشط', 'الحقوقي', 'السوداني', 'بالحكم', 'ذاته', 'التفاصيل', 'http', 'bit', 'ly', '2oMtI1V']
#
#  ------------ Stemming : stem
#  ['وزير', 'العدل', 'محمد', 'بنعبد', 'القادر', 'يكشف', 'الملك', 'محمد', 'السادس', 'قرر', 'إصدار', 'العفو', 'الصحفية', 'هاجر', 'الريسوني', 'وخطيبها', 'رفعت', 'الأمين', 'بعدما', 'حكمت', 'المحكمة', 'الابتدائية', 'بالرباط', 'عليها', 'بسنة', 'حبسا', 'نافذا', 'وغرامة', 'مالية', 'قدرها', '500', 'درهم', 'وقضت', 'حق', 'خطيبها', 'الأكاديمي', 'والناشط', 'الحقوقي', 'السوداني', 'بالحكم', 'ذاته', 'التفاصيل', 'http', 'bit', 'ly', '2omti1v']
# =================================
# تأجيل الحوار يقود علاقة أمزازي ونقابات تعليمية نحو التصعيد
#
# -------------- Tokenzer :
#  : ['تأجيل', 'الحوار', 'يقود', 'علاقة', 'أمزازي', 'ونقابات', 'تعليمية', 'نحو', 'التصعيد']
#
#  ------------ stop word removal : tokens_clean
#  ['تأجيل', 'الحوار', 'يقود', 'علاقة', 'أمزازي', 'ونقابات', 'تعليمية', 'التصعيد']
#
#  ------------ Stemming : stem
#  ['تأجيل', 'الحوار', 'يقود', 'علاقة', 'أمزازي', 'ونقابات', 'تعليمية', 'التصعيد']
# =================================
# اليوم العالمي للقضاء على الفقر.. دعوة صريحة إلى القضاء على واحد من أبشع أوجه اللامساواة التي نعيشها في عالمنا اليوم
#
# -------------- Tokenzer :
#  : ['اليوم', 'العالمي', 'للقضاء', 'على', 'الفقر', 'دعوة', 'صريحة', 'إلى', 'القضاء', 'على', 'واحد', 'من', 'أبشع', 'أوجه', 'اللامساواة', 'التي', 'نعيشها', 'في', 'عالمنا', 'اليوم']
#
#  ------------ stop word removal : tokens_clean
#  ['اليوم', 'العالمي', 'للقضاء', 'الفقر', 'دعوة', 'صريحة', 'القضاء', 'واحد', 'أبشع', 'أوجه', 'اللامساواة', 'نعيشها', 'عالمنا', 'اليوم']
#
#  ------------ Stemming : stem
#  ['اليوم', 'العالمي', 'للقضاء', 'الفقر', 'دعوة', 'صريحة', 'القضاء', 'واحد', 'أبشع', 'أوجه', 'اللامساواة', 'نعيشها', 'عالمنا', 'اليوم']
# =================================
# ساكنة "زقاق الماء" بفاس تشتكي إهمال مدرسة تحولت إلى خراب.. وتهدد سلامة العامة
#
# -------------- Tokenzer :
#  : ['ساكنة', 'زقاق', 'الماء', 'بفاس', 'تشتكي', 'إهمال', 'مدرسة', 'تحولت', 'إلى', 'خراب', 'وتهدد', 'سلامة', 'العامة']
#
#  ------------ stop word removal : tokens_clean
#  ['ساكنة', 'زقاق', 'الماء', 'بفاس', 'تشتكي', 'إهمال', 'مدرسة', 'تحولت', 'خراب', 'وتهدد', 'سلامة', 'العامة']
#
#  ------------ Stemming : stem
#  ['ساكنة', 'زقاق', 'الماء', 'بفاس', 'تشتكي', 'إهمال', 'مدرسة', 'تحولت', 'خراب', 'وتهدد', 'سلامة', 'العامة']
# =================================
# العفو عن الريسوني .. هكذا يُمارس الملك حقاً دستورياً بأهداف نبيلة
#
# -------------- Tokenzer :
#  : ['العفو', 'عن', 'الريسوني', 'هكذا', 'ي', 'مارس', 'الملك', 'حقا', 'دستوريا', 'بأهداف', 'نبيلة']
#
#  ------------ stop word removal : tokens_clean
#  ['العفو', 'الريسوني', 'ي', 'مارس', 'الملك', 'حقا', 'دستوريا', 'بأهداف', 'نبيلة']
#
#  ------------ Stemming : stem
#  ['العفو', 'الريسوني', 'ي', 'مارس', 'الملك', 'حقا', 'دستوريا', 'بأهداف', 'نبيلة']
# =================================
# "جوع منخفض" يضع المغرب ثامنا في شمال إفريقيا والشرق الأوسط
#
# -------------- Tokenzer :
#  : ['جوع', 'منخفض', 'يضع', 'المغرب', 'ثامنا', 'في', 'شمال', 'إفريقيا', 'والشرق', 'الأوسط']
#
#  ------------ stop word removal : tokens_clean
#  ['جوع', 'منخفض', 'يضع', 'المغرب', 'ثامنا', 'شمال', 'إفريقيا', 'والشرق', 'الأوسط']
#
#  ------------ Stemming : stem
#  ['جوع', 'منخفض', 'يضع', 'المغرب', 'ثامنا', 'شمال', 'إفريقيا', 'والشرق', 'الأوسط']
# =================================
# لقجع يجتمع بخاليلوزيتش لإحداث تغييرات في الطاقم التقني للمنتخب
#
# -------------- Tokenzer :
#  : ['لقجع', 'يجتمع', 'بخاليلوزيتش', 'لإحداث', 'تغييرات', 'في', 'الطاقم', 'التقني', 'للمنتخب']
#
#  ------------ stop word removal : tokens_clean
#  ['لقجع', 'يجتمع', 'بخاليلوزيتش', 'لإحداث', 'تغييرات', 'الطاقم', 'التقني', 'للمنتخب']
#
#  ------------ Stemming : stem
#  ['لقجع', 'يجتمع', 'بخاليلوزيتش', 'لإحداث', 'تغييرات', 'الطاقم', 'التقني', 'للمنتخب']
# =================================
# السولاريوم يهددك بسرطان الجلد!
#
# -------------- Tokenzer :
#  : ['السولاريوم', 'يهددك', 'بسرطان', 'الجلد']
#
#  ------------ stop word removal : tokens_clean
#  ['السولاريوم', 'يهددك', 'بسرطان', 'الجلد']
#
#  ------------ Stemming : stem
#  ['السولاريوم', 'يهددك', 'بسرطان', 'الجلد']
# =================================
# تحذيرات ترافق زيادة وزن النساء أثناء فترة الحمل
#
# -------------- Tokenzer :
#  : ['تحذيرات', 'ترافق', 'زيادة', 'وزن', 'النساء', 'أثناء', 'فترة', 'الحمل']
#
#  ------------ stop word removal : tokens_clean
#  ['تحذيرات', 'ترافق', 'زيادة', 'وزن', 'النساء', 'أثناء', 'فترة', 'الحمل']
#
#  ------------ Stemming : stem
#  ['تحذيرات', 'ترافق', 'زيادة', 'وزن', 'النساء', 'أثناء', 'فترة', 'الحمل']
# =================================
# ما هي متلازمة "عنق الهاتف الجوال"؟
#
# -------------- Tokenzer :
#  : ['ما', 'هي', 'متلازمة', 'عنق', 'الهاتف', 'الجوال']
#
#  ------------ stop word removal : tokens_clean
#  ['متلازمة', 'عنق', 'الهاتف', 'الجوال']
#
#  ------------ Stemming : stem
#  ['متلازمة', 'عنق', 'الهاتف', 'الجوال']
# =================================
# "لا دخول قبل 8:30 صباحا".. قانون جديد يمنع على أي مدرسة أن تعتمد حصصا دراسية صباحية قبل الساعة الثامنة والنصف
#
# -------------- Tokenzer :
#  : ['لا', 'دخول', 'قبل', '8', '30', 'صباحا', 'قانون', 'جديد', 'يمنع', 'على', 'أي', 'مدرسة', 'أن', 'تعتمد', 'حصصا', 'دراسية', 'صباحية', 'قبل', 'الساعة', 'الثامنة', 'والنصف']
#
#  ------------ stop word removal : tokens_clean
#  ['دخول', 'قبل', '8', '30', 'صباحا', 'قانون', 'جديد', 'يمنع', 'مدرسة', 'تعتمد', 'حصصا', 'دراسية', 'صباحية', 'قبل', 'الساعة', 'الثامنة', 'والنصف']
#
#  ------------ Stemming : stem
#  ['دخول', 'قبل', '8', '30', 'صباحا', 'قانون', 'جديد', 'يمنع', 'مدرسة', 'تعتمد', 'حصصا', 'دراسية', 'صباحية', 'قبل', 'الساعة', 'الثامنة', 'والنصف']
# =================================
# شركة إسبانية تحصل على صفقة تفوق 5 ملايين درهم لتشييد منصة معلوماتية خاصة بمدينة الدار البيضاء
#
# -------------- Tokenzer :
#  : ['شركة', 'إسبانية', 'تحصل', 'على', 'صفقة', 'تفوق', '5', 'ملايين', 'درهم', 'لتشييد', 'منصة', 'معلوماتية', 'خاصة', 'بمدينة', 'الدار', 'البيضاء']
#
#  ------------ stop word removal : tokens_clean
#  ['شركة', 'إسبانية', 'تحصل', 'صفقة', 'تفوق', '5', 'ملايين', 'درهم', 'لتشييد', 'منصة', 'معلوماتية', 'خاصة', 'بمدينة', 'الدار', 'البيضاء']
#
#  ------------ Stemming : stem
#  ['شركة', 'إسبانية', 'تحصل', 'صفقة', 'تفوق', '5', 'ملايين', 'درهم', 'لتشييد', 'منصة', 'معلوماتية', 'خاصة', 'بمدينة', 'الدار', 'البيضاء']
# =================================
# "إذا كانو زوج ناضجين فأنا مع العلاقات الرضائية.. نحن مع الحرية الفردية.. ممكن دير لينا مشاكل".. بين مؤيد ومعارض هذا رأي الشارع المغربي في العلاقات الجنسية خارج إطار الزواج
#
# -------------- Tokenzer :
#  : ['إذا', 'كانو', 'زوج', 'ناضجين', 'فأنا', 'مع', 'العلاقات', 'الرضائية', 'نحن', 'مع', 'الحرية', 'الفردية', 'ممكن', 'دير', 'لينا', 'مشاكل', 'بين', 'مؤيد', 'ومعارض', 'هذا', 'رأي', 'الشارع', 'المغربي', 'في', 'العلاقات', 'الجنسية', 'خارج', 'إطار', 'الزواج']
#
#  ------------ stop word removal : tokens_clean
#  ['كانو', 'زوج', 'ناضجين', 'فأنا', 'العلاقات', 'الرضائية', 'الحرية', 'الفردية', 'ممكن', 'دير', 'لينا', 'مشاكل', 'مؤيد', 'ومعارض', 'رأي', 'الشارع', 'المغربي', 'العلاقات', 'الجنسية', 'خارج', 'إطار', 'الزواج']
#
#  ------------ Stemming : stem
#  ['كانو', 'زوج', 'ناضجين', 'فأنا', 'العلاقات', 'الرضائية', 'الحرية', 'الفردية', 'ممكن', 'دير', 'لينا', 'مشاكل', 'مؤيد', 'ومعارض', 'رأي', 'الشارع', 'المغربي', 'العلاقات', 'الجنسية', 'خارج', 'إطار', 'الزواج']
# =================================
# وفاة أكثر من 30 معتمرًا وإصابة 5 آخرين في احتراق حافلة بالسعودية
#
# -------------- Tokenzer :
#  : ['وفاة', 'أكثر', 'من', '30', 'معتمر', 'ا', 'وإصابة', '5', 'آخرين', 'في', 'احتراق', 'حافلة', 'بالسعودية']
#
#  ------------ stop word removal : tokens_clean
#  ['وفاة', '30', 'معتمر', 'ا', 'وإصابة', '5', 'آخرين', 'احتراق', 'حافلة', 'بالسعودية']
#
#  ------------ Stemming : stem
#  ['وفاة', '30', 'معتمر', 'ا', 'وإصابة', '5', 'آخرين', 'احتراق', 'حافلة', 'بالسعودية']
# =================================
# يتيح الذكاء الاصطناعي إمكانية الوصول الفوري إلى المعلومات وقد يصل في يوم ما إلى حد التمتع بالحواس الإنسانية مثل الرؤية والشعور ما قد يشكل خطرا على مستقبل البشرية.. فهل نحن مستعدون للمواجهة؟
#
# -------------- Tokenzer :
#  : ['يتيح', 'الذكاء', 'الاصطناعي', 'إمكانية', 'الوصول', 'الفوري', 'إلى', 'المعلومات', 'وقد', 'يصل', 'في', 'يوم', 'ما', 'إلى', 'حد', 'التمتع', 'بالحواس', 'الإنسانية', 'مثل', 'الرؤية', 'والشعور', 'ما', 'قد', 'يشكل', 'خطرا', 'على', 'مستقبل', 'البشرية', 'فهل', 'نحن', 'مستعدون', 'للمواجهة']
#
#  ------------ stop word removal : tokens_clean
#  ['يتيح', 'الذكاء', 'الاصطناعي', 'إمكانية', 'الوصول', 'الفوري', 'المعلومات', 'وقد', 'يصل', 'يوم', 'حد', 'التمتع', 'بالحواس', 'الإنسانية', 'مثل', 'الرؤية', 'والشعور', 'يشكل', 'خطرا', 'مستقبل', 'البشرية', 'فهل', 'مستعدون', 'للمواجهة']
#
#  ------------ Stemming : stem
#  ['يتيح', 'الذكاء', 'الاصطناعي', 'إمكانية', 'الوصول', 'الفوري', 'المعلومات', 'وقد', 'يصل', 'يوم', 'حد', 'التمتع', 'بالحواس', 'الإنسانية', 'مثل', 'الرؤية', 'والشعور', 'يشكل', 'خطرا', 'مستقبل', 'البشرية', 'فهل', 'مستعدون', 'للمواجهة']
# =================================
# خطيب هاجر الريسوني متأثرا: "سعدت كثيرا بالعفو الملكي.. والحرية هي كل شيء"
#
# -------------- Tokenzer :
#  : ['خطيب', 'هاجر', 'الريسوني', 'متأثرا', 'سعدت', 'كثيرا', 'بالعفو', 'الملكي', 'والحرية', 'هي', 'كل', 'شيء']
#
#  ------------ stop word removal : tokens_clean
#  ['خطيب', 'هاجر', 'الريسوني', 'متأثرا', 'سعدت', 'كثيرا', 'بالعفو', 'الملكي', 'والحرية', 'شيء']
#
#  ------------ Stemming : stem
#  ['خطيب', 'هاجر', 'الريسوني', 'متأثرا', 'سعدت', 'كثيرا', 'بالعفو', 'الملكي', 'والحرية', 'شيء']
# =================================
# اليوم العالمي للتغذية.. مناسبة لتعزيز الوعي والعمل من أجل محاربة الجوع عبر العالم
#
# -------------- Tokenzer :
#  : ['اليوم', 'العالمي', 'للتغذية', 'مناسبة', 'لتعزيز', 'الوعي', 'والعمل', 'من', 'أجل', 'محاربة', 'الجوع', 'عبر', 'العالم']
#
#  ------------ stop word removal : tokens_clean
#  ['اليوم', 'العالمي', 'للتغذية', 'مناسبة', 'لتعزيز', 'الوعي', 'والعمل', 'أجل', 'محاربة', 'الجوع', 'عبر', 'العالم']
#
#  ------------ Stemming : stem
#  ['اليوم', 'العالمي', 'للتغذية', 'مناسبة', 'لتعزيز', 'الوعي', 'والعمل', 'أجل', 'محاربة', 'الجوع', 'عبر', 'العالم']
# =================================
# هاجر الريسوني بعد العفو: "أشكر كل من تضامن معي.. وهذا العفو كان تصحيحا للظلم الذي تعرضنا له"
#
# -------------- Tokenzer :
#  : ['هاجر', 'الريسوني', 'بعد', 'العفو', 'أشكر', 'كل', 'من', 'تضامن', 'معي', 'وهذا', 'العفو', 'كان', 'تصحيحا', 'للظلم', 'الذي', 'تعرضنا', 'له']
#
#  ------------ stop word removal : tokens_clean
#  ['هاجر', 'الريسوني', 'العفو', 'أشكر', 'تضامن', 'معي', 'وهذا', 'العفو', 'كان', 'تصحيحا', 'للظلم', 'تعرضنا']
#
#  ------------ Stemming : stem
#  ['هاجر', 'الريسوني', 'العفو', 'أشكر', 'تضامن', 'معي', 'وهذا', 'العفو', 'كان', 'تصحيحا', 'للظلم', 'تعرضنا']
# =================================
# شاهد .. لحظة خروج هاجر الريسوني من سجن العرجات بفضل العفو الملكي
#
# -------------- Tokenzer :
#  : ['شاهد', 'لحظة', 'خروج', 'هاجر', 'الريسوني', 'من', 'سجن', 'العرجات', 'بفضل', 'العفو', 'الملكي']
#
#  ------------ stop word removal : tokens_clean
#  ['شاهد', 'لحظة', 'خروج', 'هاجر', 'الريسوني', 'سجن', 'العرجات', 'بفضل', 'العفو', 'الملكي']
#
#  ------------ Stemming : stem
#  ['شاهد', 'لحظة', 'خروج', 'هاجر', 'الريسوني', 'سجن', 'العرجات', 'بفضل', 'العفو', 'الملكي']
# =================================
# "يا ولدي..الهواتف أفسدت الكُتب كلشي ولا كي طيليشارجي".. فيصل شاب يكرّم والده بالكتب وباستعمال "هاشتاغ" خاص يدعو من خلاله إلى شراء الكتب للتشجيع على القراءة وإعطاء أمل لهذه التجارة أن تستمر
#
# -------------- Tokenzer :
#  : ['يا', 'ولدي', 'الهواتف', 'أفسدت', 'الك', 'تب', 'كلشي', 'ولا', 'كي', 'طيليشارجي', 'فيصل', 'شاب', 'يكر', 'م', 'والده', 'بالكتب', 'وباستعمال', 'هاشتاغ', 'خاص', 'يدعو', 'من', 'خلاله', 'إلى', 'شراء', 'الكتب', 'للتشجيع', 'على', 'القراءة', 'وإعطاء', 'أمل', 'لهذه', 'التجارة', 'أن', 'تستمر']
#
#  ------------ stop word removal : tokens_clean
#  ['ولدي', 'الهواتف', 'أفسدت', 'الك', 'تب', 'كلشي', 'طيليشارجي', 'فيصل', 'شاب', 'يكر', 'م', 'والده', 'بالكتب', 'وباستعمال', 'هاشتاغ', 'خاص', 'يدعو', 'خلاله', 'شراء', 'الكتب', 'للتشجيع', 'القراءة', 'وإعطاء', 'أمل', 'لهذه', 'التجارة', 'تستمر']
#
#  ------------ Stemming : stem
#  ['ولدي', 'الهواتف', 'أفسدت', 'الك', 'تب', 'كلشي', 'طيليشارجي', 'فيصل', 'شاب', 'يكر', 'م', 'والده', 'بالكتب', 'وباستعمال', 'هاشتاغ', 'خاص', 'يدعو', 'خلاله', 'شراء', 'الكتب', 'للتشجيع', 'القراءة', 'وإعطاء', 'أمل', 'لهذه', 'التجارة', 'تستمر']
# =================================
# هذه أسباب تهزّ ثقة المغاربة في "أسود خاليلوزيتش" .. حجي وتصريحات ساخنة وحرس قديم
#
# -------------- Tokenzer :
#  : ['هذه', 'أسباب', 'تهز', 'ثقة', 'المغاربة', 'في', 'أسود', 'خاليلوزيتش', 'حجي', 'وتصريحات', 'ساخنة', 'وحرس', 'قديم']
#
#  ------------ stop word removal : tokens_clean
#  ['أسباب', 'تهز', 'ثقة', 'المغاربة', 'أسود', 'خاليلوزيتش', 'حجي', 'وتصريحات', 'ساخنة', 'وحرس', 'قديم']
#
#  ------------ Stemming : stem
#  ['أسباب', 'تهز', 'ثقة', 'المغاربة', 'أسود', 'خاليلوزيتش', 'حجي', 'وتصريحات', 'ساخنة', 'وحرس', 'قديم']
# =================================
# بالصور.. لحظات فرح أثناء مغادرة الصحافية هاجر الريسوني ومن معها سجن العرجات بعد العفو الملكي
#
# -------------- Tokenzer :
#  : ['بالصور', 'لحظات', 'فرح', 'أثناء', 'مغادرة', 'الصحافية', 'هاجر', 'الريسوني', 'ومن', 'معها', 'سجن', 'العرجات', 'بعد', 'العفو', 'الملكي']
#
#  ------------ stop word removal : tokens_clean
#  ['بالصور', 'لحظات', 'فرح', 'أثناء', 'مغادرة', 'الصحافية', 'هاجر', 'الريسوني', 'معها', 'سجن', 'العرجات', 'العفو', 'الملكي']
#
#  ------------ Stemming : stem
#  ['بالصور', 'لحظات', 'فرح', 'أثناء', 'مغادرة', 'الصحافية', 'هاجر', 'الريسوني', 'معها', 'سجن', 'العرجات', 'العفو', 'الملكي']
# =================================
# محامي هاجر الريسوني: هذا العفو جاء ليصحح الأخطاء والارتباكات التي شابت هذا الملف
#
# -------------- Tokenzer :
#  : ['محامي', 'هاجر', 'الريسوني', 'هذا', 'العفو', 'جاء', 'ليصحح', 'الأخطاء', 'والارتباكات', 'التي', 'شابت', 'هذا', 'الملف']
#
#  ------------ stop word removal : tokens_clean
#  ['محامي', 'هاجر', 'الريسوني', 'العفو', 'جاء', 'ليصحح', 'الأخطاء', 'والارتباكات', 'شابت', 'الملف']
#
#  ------------ Stemming : stem
#  ['محامي', 'هاجر', 'الريسوني', 'العفو', 'جاء', 'ليصحح', 'الأخطاء', 'والارتباكات', 'شابت', 'الملف']
# =================================
# لحظة مغادرة الصحافية هاجر الريسوني ومن معها السجن بعد العفو الملكي
#
# -------------- Tokenzer :
#  : ['لحظة', 'مغادرة', 'الصحافية', 'هاجر', 'الريسوني', 'ومن', 'معها', 'السجن', 'بعد', 'العفو', 'الملكي']
#
#  ------------ stop word removal : tokens_clean
#  ['لحظة', 'مغادرة', 'الصحافية', 'هاجر', 'الريسوني', 'معها', 'السجن', 'العفو', 'الملكي']
#
#  ------------ Stemming : stem
#  ['لحظة', 'مغادرة', 'الصحافية', 'هاجر', 'الريسوني', 'معها', 'السجن', 'العفو', 'الملكي']
# =================================
# الملك محمد السادس يعفو عن الصحافية هاجر الريسوني وخطيبها ومن معهما في قضية أثارت الكثير من الجدل بتهم تتعلق بالفساد والإجهاض
#
# -------------- Tokenzer :
#  : ['الملك', 'محمد', 'السادس', 'يعفو', 'عن', 'الصحافية', 'هاجر', 'الريسوني', 'وخطيبها', 'ومن', 'معهما', 'في', 'قضية', 'أثارت', 'الكثير', 'من', 'الجدل', 'بتهم', 'تتعلق', 'بالفساد', 'والإجهاض']
#
#  ------------ stop word removal : tokens_clean
#  ['الملك', 'محمد', 'السادس', 'يعفو', 'الصحافية', 'هاجر', 'الريسوني', 'وخطيبها', 'معهما', 'قضية', 'أثارت', 'الكثير', 'الجدل', 'بتهم', 'تتعلق', 'بالفساد', 'والإجهاض']
#
#  ------------ Stemming : stem
#  ['الملك', 'محمد', 'السادس', 'يعفو', 'الصحافية', 'هاجر', 'الريسوني', 'وخطيبها', 'معهما', 'قضية', 'أثارت', 'الكثير', 'الجدل', 'بتهم', 'تتعلق', 'بالفساد', 'والإجهاض']
# =================================
# بشرى للمغاربة .. تراجع أسعار النفط يرحم جيوب المغاربة ويخفض أثمان المحروقات
#
# -------------- Tokenzer :
#  : ['بشرى', 'للمغاربة', 'تراجع', 'أسعار', 'النفط', 'يرحم', 'جيوب', 'المغاربة', 'ويخفض', 'أثمان', 'المحروقات']
#
#  ------------ stop word removal : tokens_clean
#  ['بشرى', 'للمغاربة', 'تراجع', 'أسعار', 'النفط', 'يرحم', 'جيوب', 'المغاربة', 'ويخفض', 'أثمان', 'المحروقات']
#
#  ------------ Stemming : stem
#  ['بشرى', 'للمغاربة', 'تراجع', 'أسعار', 'النفط', 'يرحم', 'جيوب', 'المغاربة', 'ويخفض', 'أثمان', 'المحروقات']
# =================================
# سيدة مسنة تصبح أكبر أم تنجب مولودا في العالم بعدما أنجبت طفلة بعد 6 أشهر ونصف الشهر من الحمل
#
# -------------- Tokenzer :
#  : ['سيدة', 'مسنة', 'تصبح', 'أكبر', 'أم', 'تنجب', 'مولودا', 'في', 'العالم', 'بعدما', 'أنجبت', 'طفلة', 'بعد', '6', 'أشهر', 'ونصف', 'الشهر', 'من', 'الحمل']
#
#  ------------ stop word removal : tokens_clean
#  ['سيدة', 'مسنة', 'تصبح', 'أكبر', 'تنجب', 'مولودا', 'العالم', 'بعدما', 'أنجبت', 'طفلة', '6', 'أشهر', 'ونصف', 'الشهر', 'الحمل']
#
#  ------------ Stemming : stem
#  ['سيدة', 'مسنة', 'تصبح', 'أكبر', 'تنجب', 'مولودا', 'العالم', 'بعدما', 'أنجبت', 'طفلة', '6', 'أشهر', 'ونصف', 'الشهر', 'الحمل']
# =================================
# هذه دوافع إغفال غُوتيريس لدور مجلس حقوق الإنسان في الصحراء
#
# -------------- Tokenzer :
#  : ['هذه', 'دوافع', 'إغفال', 'غ', 'وتيريس', 'لدور', 'مجلس', 'حقوق', 'الإنسان', 'في', 'الصحراء']
#
#  ------------ stop word removal : tokens_clean
#  ['دوافع', 'إغفال', 'غ', 'وتيريس', 'لدور', 'مجلس', 'حقوق', 'الإنسان', 'الصحراء']
#
#  ------------ Stemming : stem
#  ['دوافع', 'إغفال', 'غ', 'وتيريس', 'لدور', 'مجلس', 'حقوق', 'الإنسان', 'الصحراء']
# =================================
# 52 ألف تلميذ من المدارس الخصوصية يلتحقون بالمدارس العمومية ووزير التربية الوطنية يؤكد أن المدرسة العمومية تتوفر على عناصر جاذبية.. هل تتفق مع الوزير؟
#
# -------------- Tokenzer :
#  : ['52', 'ألف', 'تلميذ', 'من', 'المدارس', 'الخصوصية', 'يلتحقون', 'بالمدارس', 'العمومية', 'ووزير', 'التربية', 'الوطنية', 'يؤكد', 'أن', 'المدرسة', 'العمومية', 'تتوفر', 'على', 'عناصر', 'جاذبية', 'هل', 'تتفق', 'مع', 'الوزير']
#
#  ------------ stop word removal : tokens_clean
#  ['52', 'ألف', 'تلميذ', 'المدارس', 'الخصوصية', 'يلتحقون', 'بالمدارس', 'العمومية', 'ووزير', 'التربية', 'الوطنية', 'يؤكد', 'المدرسة', 'العمومية', 'تتوفر', 'عناصر', 'جاذبية', 'تتفق', 'الوزير']
#
#  ------------ Stemming : stem
#  ['52', 'ألف', 'تلميذ', 'المدارس', 'الخصوصية', 'يلتحقون', 'بالمدارس', 'العمومية', 'ووزير', 'التربية', 'الوطنية', 'يؤكد', 'المدرسة', 'العمومية', 'تتوفر', 'عناصر', 'جاذبية', 'تتفق', 'الوزير']
# =================================
# معرض الفرس للجديدة.. شاهد عرضا مبهرا لفرق الفروسية التابعة للقوات المسلحة الملكية
#
# -------------- Tokenzer :
#  : ['معرض', 'الفرس', 'للجديدة', 'شاهد', 'عرضا', 'مبهرا', 'لفرق', 'الفروسية', 'التابعة', 'للقوات', 'المسلحة', 'الملكية']
#
#  ------------ stop word removal : tokens_clean
#  ['معرض', 'الفرس', 'للجديدة', 'شاهد', 'عرضا', 'مبهرا', 'لفرق', 'الفروسية', 'التابعة', 'للقوات', 'المسلحة', 'الملكية']
#
#  ------------ Stemming : stem
#  ['معرض', 'الفرس', 'للجديدة', 'شاهد', 'عرضا', 'مبهرا', 'لفرق', 'الفروسية', 'التابعة', 'للقوات', 'المسلحة', 'الملكية']
# =================================
# ضربة موجعة لفيسبوك.. العملة الرقمية "ليبرا" تخسر 5 من أكبر شركائها قبل موعد انطلاقها في 2020
#
# -------------- Tokenzer :
#  : ['ضربة', 'موجعة', 'لفيسبوك', 'العملة', 'الرقمية', 'ليبرا', 'تخسر', '5', 'من', 'أكبر', 'شركائها', 'قبل', 'موعد', 'انطلاقها', 'في', '2020']
#
#  ------------ stop word removal : tokens_clean
#  ['ضربة', 'موجعة', 'لفيسبوك', 'العملة', 'الرقمية', 'ليبرا', 'تخسر', '5', 'أكبر', 'شركائها', 'قبل', 'موعد', 'انطلاقها', '2020']
#
#  ------------ Stemming : stem
#  ['ضربة', 'موجعة', 'لفيسبوك', 'العملة', 'الرقمية', 'ليبرا', 'تخسر', '5', 'أكبر', 'شركائها', 'قبل', 'موعد', 'انطلاقها', '2020']
# =================================
# عاجل .. الملك محمد السادس يصدر عفوا عن الصحافية هاجر الريسوني
#
# -------------- Tokenzer :
#  : ['عاجل', 'الملك', 'محمد', 'السادس', 'يصدر', 'عفوا', 'عن', 'الصحافية', 'هاجر', 'الريسوني']
#
#  ------------ stop word removal : tokens_clean
#  ['عاجل', 'الملك', 'محمد', 'السادس', 'يصدر', 'عفوا', 'الصحافية', 'هاجر', 'الريسوني']
#
#  ------------ Stemming : stem
#  ['عاجل', 'الملك', 'محمد', 'السادس', 'يصدر', 'عفوا', 'الصحافية', 'هاجر', 'الريسوني']
# =================================
# إثقال كاهل ميزانية الدولة بتقاعد "الوزراء المغادرين" يصل البرلمان
#
# -------------- Tokenzer :
#  : ['إثقال', 'كاهل', 'ميزانية', 'الدولة', 'بتقاعد', 'الوزراء', 'المغادرين', 'يصل', 'البرلمان']
#
#  ------------ stop word removal : tokens_clean
#  ['إثقال', 'كاهل', 'ميزانية', 'الدولة', 'بتقاعد', 'الوزراء', 'المغادرين', 'يصل', 'البرلمان']
#
#  ------------ Stemming : stem
#  ['إثقال', 'كاهل', 'ميزانية', 'الدولة', 'بتقاعد', 'الوزراء', 'المغادرين', 'يصل', 'البرلمان']
# =================================
# "المغرب ليس غابة .. وترخيص العلاقات الجنسية خارج الزواج مرفوض" (مواطنون)
#
# -------------- Tokenzer :
#  : ['المغرب', 'ليس', 'غابة', 'وترخيص', 'العلاقات', 'الجنسية', 'خارج', 'الزواج', 'مرفوض', 'مواطنون']
#
#  ------------ stop word removal : tokens_clean
#  ['المغرب', 'غابة', 'وترخيص', 'العلاقات', 'الجنسية', 'خارج', 'الزواج', 'مرفوض', 'مواطنون']
#
#  ------------ Stemming : stem
#  ['المغرب', 'غابة', 'وترخيص', 'العلاقات', 'الجنسية', 'خارج', 'الزواج', 'مرفوض', 'مواطنون']
# =================================
# بعد الخسارة.. الجمهور المغربي غير "راضٍ" عن أداء المدرب خليلوزيتش مع المنتخب
#
# -------------- Tokenzer :
#  : ['بعد', 'الخسارة', 'الجمهور', 'المغربي', 'غير', 'راض', 'عن', 'أداء', 'المدرب', 'خليلوزيتش', 'مع', 'المنتخب']
#
#  ------------ stop word removal : tokens_clean
#  ['الخسارة', 'الجمهور', 'المغربي', 'راض', 'أداء', 'المدرب', 'خليلوزيتش', 'المنتخب']
#
#  ------------ Stemming : stem
#  ['الخسارة', 'الجمهور', 'المغربي', 'راض', 'أداء', 'المدرب', 'خليلوزيتش', 'المنتخب']
# =================================
# الجمهور المغربي ينتفض ضد خاليلوزيتش ويتهم المدرب بإهانة اللاعب المحلي (فيديو)
#
# -------------- Tokenzer :
#  : ['الجمهور', 'المغربي', 'ينتفض', 'ضد', 'خاليلوزيتش', 'ويتهم', 'المدرب', 'بإهانة', 'اللاعب', 'المحلي', 'فيديو']
#
#  ------------ stop word removal : tokens_clean
#  ['الجمهور', 'المغربي', 'ينتفض', 'ضد', 'خاليلوزيتش', 'ويتهم', 'المدرب', 'بإهانة', 'اللاعب', 'المحلي', 'فيديو']
#
#  ------------ Stemming : stem
#  ['الجمهور', 'المغربي', 'ينتفض', 'ضد', 'خاليلوزيتش', 'ويتهم', 'المدرب', 'بإهانة', 'اللاعب', 'المحلي', 'فيديو']
# =================================
# اشتباكات مع الشرطة، حرائق وشل حركة المرور..تظاهر الآلاف من سكان إقليم كاتالونيا على الأحكام ضد قادة الانفصال
#
# -------------- Tokenzer :
#  : ['اشتباكات', 'مع', 'الشرطة', 'حرائق', 'وشل', 'حركة', 'المرور', 'تظاهر', 'الآلاف', 'من', 'سكان', 'إقليم', 'كاتالونيا', 'على', 'الأحكام', 'ضد', 'قادة', 'الانفصال']
#
#  ------------ stop word removal : tokens_clean
#  ['اشتباكات', 'الشرطة', 'حرائق', 'وشل', 'حركة', 'المرور', 'تظاهر', 'الآلاف', 'سكان', 'إقليم', 'كاتالونيا', 'الأحكام', 'ضد', 'قادة', 'الانفصال']
#
#  ------------ Stemming : stem
#  ['اشتباكات', 'الشرطة', 'حرائق', 'وشل', 'حركة', 'المرور', 'تظاهر', 'الآلاف', 'سكان', 'إقليم', 'كاتالونيا', 'الأحكام', 'ضد', 'قادة', 'الانفصال']
# =================================
# انتخابات تونس تبعث آمال الجزائريين بالتخلص من "رموز النظام"
#
# -------------- Tokenzer :
#  : ['انتخابات', 'تونس', 'تبعث', 'آمال', 'الجزائريين', 'بالتخلص', 'من', 'رموز', 'النظام']
#
#  ------------ stop word removal : tokens_clean
#  ['انتخابات', 'تونس', 'تبعث', 'آمال', 'الجزائريين', 'بالتخلص', 'رموز', 'النظام']
#
#  ------------ Stemming : stem
#  ['انتخابات', 'تونس', 'تبعث', 'آمال', 'الجزائريين', 'بالتخلص', 'رموز', 'النظام']
# =================================
# حريق جديد بسبب شاحن هاتف.. هذه تفاصيل الحادث الذي هز مدينة الدار البيضاء وراح ضحيته طفل يبلغ من العمر 3 سنوات
#
# -------------- Tokenzer :
#  : ['حريق', 'جديد', 'بسبب', 'شاحن', 'هاتف', 'هذه', 'تفاصيل', 'الحادث', 'الذي', 'هز', 'مدينة', 'الدار', 'البيضاء', 'وراح', 'ضحيته', 'طفل', 'يبلغ', 'من', 'العمر', '3', 'سنوات']
#
#  ------------ stop word removal : tokens_clean
#  ['حريق', 'جديد', 'بسبب', 'شاحن', 'هاتف', 'تفاصيل', 'الحادث', 'هز', 'مدينة', 'الدار', 'البيضاء', 'وراح', 'ضحيته', 'طفل', 'يبلغ', 'العمر', '3', 'سنوات']
#
#  ------------ Stemming : stem
#  ['حريق', 'جديد', 'بسبب', 'شاحن', 'هاتف', 'تفاصيل', 'الحادث', 'هز', 'مدينة', 'الدار', 'البيضاء', 'وراح', 'ضحيته', 'طفل', 'يبلغ', 'العمر', '3', 'سنوات']
# =================================
# الإمارات تعلن تأسيس أول جامعة متخصصة في أبحاث الذكاء الاصطناعي على مستوى العالم
#
# -------------- Tokenzer :
#  : ['الإمارات', 'تعلن', 'تأسيس', 'أول', 'جامعة', 'متخصصة', 'في', 'أبحاث', 'الذكاء', 'الاصطناعي', 'على', 'مستوى', 'العالم']
#
#  ------------ stop word removal : tokens_clean
#  ['الإمارات', 'تعلن', 'تأسيس', 'أول', 'جامعة', 'متخصصة', 'أبحاث', 'الذكاء', 'الاصطناعي', 'مستوى', 'العالم']
#
#  ------------ Stemming : stem
#  ['الإمارات', 'تعلن', 'تأسيس', 'أول', 'جامعة', 'متخصصة', 'أبحاث', 'الذكاء', 'الاصطناعي', 'مستوى', 'العالم']
# =================================
# الحكومة ترفض خفض الضريبة على الدخل في "مالية سنة 2020"
#
# -------------- Tokenzer :
#  : ['الحكومة', 'ترفض', 'خفض', 'الضريبة', 'على', 'الدخل', 'في', 'مالية', 'سنة', '2020']
#
#  ------------ stop word removal : tokens_clean
#  ['الحكومة', 'ترفض', 'خفض', 'الضريبة', 'الدخل', 'مالية', 'سنة', '2020']
#
#  ------------ Stemming : stem
#  ['الحكومة', 'ترفض', 'خفض', 'الضريبة', 'الدخل', 'مالية', 'سنة', '2020']
# =================================
# "اللاعب المحلي ضعيف بدنيا مقارنة مع مستوى اللاعب في أوروبا" هكذا صرّح الناخب الوطني وحيد خاليلوزيتش بعد "وديّة وجدة" أمام المنتخب الليبي التي انتهت بالتعادل الإيجابي 1-1.. ليعود بعد أيام ويسقط بثلاثية أمام… More منتخب الغابون في "وديّة طنجة"
# ما رأيك في تصريحات الناخب الوطني مقارنة بالمستوى الذي أبان عنه في أولى مبارياته كمدرب للمنتخب المغربي؟
#
# -------------- Tokenzer :
#  : ['اللاعب', 'المحلي', 'ضعيف', 'بدنيا', 'مقارنة', 'مع', 'مستوى', 'اللاعب', 'في', 'أوروبا', 'هكذا', 'صر', 'ح', 'الناخب', 'الوطني', 'وحيد', 'خاليلوزيتش', 'بعد', 'ودي', 'ة', 'وجدة', 'أمام', 'المنتخب', 'الليبي', 'التي', 'انتهت', 'بالتعادل', 'الإيجابي', '1', '1', 'ليعود', 'بعد', 'أيام', 'ويسقط', 'بثلاثية', 'أمام', 'More', 'منتخب', 'الغابون', 'في', 'ودي', 'ة', 'طنجة', 'ما', 'رأيك', 'في', 'تصريحات', 'الناخب', 'الوطني', 'مقارنة', 'بالمستوى', 'الذي', 'أبان', 'عنه', 'في', 'أولى', 'مبارياته', 'كمدرب', 'للمنتخب', 'المغربي']
#
#  ------------ stop word removal : tokens_clean
#  ['اللاعب', 'المحلي', 'ضعيف', 'بدنيا', 'مقارنة', 'مستوى', 'اللاعب', 'أوروبا', 'صر', 'ح', 'الناخب', 'الوطني', 'وحيد', 'خاليلوزيتش', 'ودي', 'ة', 'وجدة', 'أمام', 'المنتخب', 'الليبي', 'انتهت', 'بالتعادل', 'الإيجابي', '1', '1', 'ليعود', 'أيام', 'ويسقط', 'بثلاثية', 'أمام', 'More', 'منتخب', 'الغابون', 'ودي', 'ة', 'طنجة', 'رأيك', 'تصريحات', 'الناخب', 'الوطني', 'مقارنة', 'بالمستوى', 'أبان', 'عنه', 'أولى', 'مبارياته', 'كمدرب', 'للمنتخب', 'المغربي']
#
#  ------------ Stemming : stem
#  ['اللاعب', 'المحلي', 'ضعيف', 'بدنيا', 'مقارنة', 'مستوى', 'اللاعب', 'أوروبا', 'صر', 'ح', 'الناخب', 'الوطني', 'وحيد', 'خاليلوزيتش', 'ودي', 'ة', 'وجدة', 'أمام', 'المنتخب', 'الليبي', 'انتهت', 'بالتعادل', 'الإيجابي', '1', '1', 'ليعود', 'أيام', 'ويسقط', 'بثلاثية', 'أمام', 'more', 'منتخب', 'الغابون', 'ودي', 'ة', 'طنجة', 'رأيك', 'تصريحات', 'الناخب', 'الوطني', 'مقارنة', 'بالمستوى', 'أبان', 'عنه', 'أولى', 'مبارياته', 'كمدرب', 'للمنتخب', 'المغربي']
# =================================
# شرطي يستعمل السلاح ضد شخص في حالة اندفاع قويّة .. رصاصة بالكتف تبعد الخطر عن الأمنيّين والمواطنين
#
# -------------- Tokenzer :
#  : ['شرطي', 'يستعمل', 'السلاح', 'ضد', 'شخص', 'في', 'حالة', 'اندفاع', 'قوي', 'ة', 'رصاصة', 'بالكتف', 'تبعد', 'الخطر', 'عن', 'الأمني', 'ين', 'والمواطنين']
#
#  ------------ stop word removal : tokens_clean
#  ['شرطي', 'يستعمل', 'السلاح', 'ضد', 'شخص', 'حالة', 'اندفاع', 'قوي', 'ة', 'رصاصة', 'بالكتف', 'تبعد', 'الخطر', 'الأمني', 'ين', 'والمواطنين']
#
#  ------------ Stemming : stem
#  ['شرطي', 'يستعمل', 'السلاح', 'ضد', 'شخص', 'حالة', 'اندفاع', 'قوي', 'ة', 'رصاصة', 'بالكتف', 'تبعد', 'الخطر', 'الأمني', 'ين', 'والمواطنين']
# =================================
# أسرة هولندية تنتظر نهاية العالم في قبو بمزرعة نائية منذ 9 سنوات.. تعرف على هذه القصة الغريبة
#
# -------------- Tokenzer :
#  : ['أسرة', 'هولندية', 'تنتظر', 'نهاية', 'العالم', 'في', 'قبو', 'بمزرعة', 'نائية', 'منذ', '9', 'سنوات', 'تعرف', 'على', 'هذه', 'القصة', 'الغريبة']
#
#  ------------ stop word removal : tokens_clean
#  ['أسرة', 'هولندية', 'تنتظر', 'نهاية', 'العالم', 'قبو', 'بمزرعة', 'نائية', '9', 'سنوات', 'تعرف', 'القصة', 'الغريبة']
#
#  ------------ Stemming : stem
#  ['أسرة', 'هولندية', 'تنتظر', 'نهاية', 'العالم', 'قبو', 'بمزرعة', 'نائية', '9', 'سنوات', 'تعرف', 'القصة', 'الغريبة']
# =================================
# هكَذا استقبَل لاعبُو المنتَخب الوطنيّ المغربيّ الهزِيمة أمَام الغابُون (فيديو)
#
# -------------- Tokenzer :
#  : ['هك', 'ذا', 'استقب', 'ل', 'لاعب', 'و', 'المنت', 'خب', 'الوطني', 'المغربي', 'الهز', 'يمة', 'أم', 'ام', 'الغاب', 'ون', 'فيديو']
#
#  ------------ stop word removal : tokens_clean
#  ['هك', 'استقب', 'ل', 'لاعب', 'و', 'المنت', 'خب', 'الوطني', 'المغربي', 'الهز', 'يمة', 'ام', 'الغاب', 'ون', 'فيديو']
#
#  ------------ Stemming : stem
#  ['هك', 'استقب', 'ل', 'لاعب', 'و', 'المنت', 'خب', 'الوطني', 'المغربي', 'الهز', 'يمة', 'ام', 'الغاب', 'ون', 'فيديو']
# =================================
# في مثل هذا اليوم.. 16 أكتوبر سنة 1975، أعلن الملك الراحل الحسن الثاني عن تنظيم المسيرة الخضراء ولبى المغاربة نداء الوطن لتحرير الأقاليم الجنوبية واستكمال الوحدة الترابية
#
# -------------- Tokenzer :
#  : ['في', 'مثل', 'هذا', 'اليوم', '16', 'أكتوبر', 'سنة', '1975', 'أعلن', 'الملك', 'الراحل', 'الحسن', 'الثاني', 'عن', 'تنظيم', 'المسيرة', 'الخضراء', 'ولبى', 'المغاربة', 'نداء', 'الوطن', 'لتحرير', 'الأقاليم', 'الجنوبية', 'واستكمال', 'الوحدة', 'الترابية']
#
#  ------------ stop word removal : tokens_clean
#  ['مثل', 'اليوم', '16', 'أكتوبر', 'سنة', '1975', 'أعلن', 'الملك', 'الراحل', 'الحسن', 'الثاني', 'تنظيم', 'المسيرة', 'الخضراء', 'ولبى', 'المغاربة', 'نداء', 'الوطن', 'لتحرير', 'الأقاليم', 'الجنوبية', 'واستكمال', 'الوحدة', 'الترابية']
#
#  ------------ Stemming : stem
#  ['مثل', 'اليوم', '16', 'أكتوبر', 'سنة', '1975', 'أعلن', 'الملك', 'الراحل', 'الحسن', 'الثاني', 'تنظيم', 'المسيرة', 'الخضراء', 'ولبى', 'المغاربة', 'نداء', 'الوطن', 'لتحرير', 'الأقاليم', 'الجنوبية', 'واستكمال', 'الوحدة', 'الترابية']
# =================================
# بعد يوم من انحراف عربات عن السكّة .. القطارات تعود للسير بين الدار البيضاء ومراكش
#
# -------------- Tokenzer :
#  : ['بعد', 'يوم', 'من', 'انحراف', 'عربات', 'عن', 'السك', 'ة', 'القطارات', 'تعود', 'للسير', 'بين', 'الدار', 'البيضاء', 'ومراكش']
#
#  ------------ stop word removal : tokens_clean
#  ['يوم', 'انحراف', 'عربات', 'السك', 'ة', 'القطارات', 'تعود', 'للسير', 'الدار', 'البيضاء', 'ومراكش']
#
#  ------------ Stemming : stem
#  ['يوم', 'انحراف', 'عربات', 'السك', 'ة', 'القطارات', 'تعود', 'للسير', 'الدار', 'البيضاء', 'ومراكش']
# =================================
# مزارع بلجيكي يفوز في مسابقة لوزن اليقطين إذ بلغ وزن يقطينته نحو 1013 كيلوغراما
#
# -------------- Tokenzer :
#  : ['مزارع', 'بلجيكي', 'يفوز', 'في', 'مسابقة', 'لوزن', 'اليقطين', 'إذ', 'بلغ', 'وزن', 'يقطينته', 'نحو', '1013', 'كيلوغراما']
#
#  ------------ stop word removal : tokens_clean
#  ['مزارع', 'بلجيكي', 'يفوز', 'مسابقة', 'لوزن', 'اليقطين', 'بلغ', 'وزن', 'يقطينته', '1013', 'كيلوغراما']
#
#  ------------ Stemming : stem
#  ['مزارع', 'بلجيكي', 'يفوز', 'مسابقة', 'لوزن', 'اليقطين', 'بلغ', 'وزن', 'يقطينته', '1013', 'كيلوغراما']
# =================================
# دافع وزير التربية الوطنية والتكوين المهني والتعليم العالي والبحث العلمي، سعيد أمزازي، على جودة المدرسة العمومية، كاشفا أنه خلال الموسم الدراسي الحالي التحق 52 ألف تلميذ من المدارس الخصوصية بالمدارس العمومية.. لو أتيحت لك الفرصة، هل ستحول ابنك من المدرسة الخصوصية إلى العمومية؟
#
# -------------- Tokenzer :
#  : ['دافع', 'وزير', 'التربية', 'الوطنية', 'والتكوين', 'المهني', 'والتعليم', 'العالي', 'والبحث', 'العلمي', 'سعيد', 'أمزازي', 'على', 'جودة', 'المدرسة', 'العمومية', 'كاشفا', 'أنه', 'خلال', 'الموسم', 'الدراسي', 'الحالي', 'التحق', '52', 'ألف', 'تلميذ', 'من', 'المدارس', 'الخصوصية', 'بالمدارس', 'العمومية', 'لو', 'أتيحت', 'لك', 'الفرصة', 'هل', 'ستحول', 'ابنك', 'من', 'المدرسة', 'الخصوصية', 'إلى', 'العمومية']
#
#  ------------ stop word removal : tokens_clean
#  ['دافع', 'وزير', 'التربية', 'الوطنية', 'والتكوين', 'المهني', 'والتعليم', 'العالي', 'والبحث', 'العلمي', 'سعيد', 'أمزازي', 'جودة', 'المدرسة', 'العمومية', 'كاشفا', 'أنه', 'خلال', 'الموسم', 'الدراسي', 'الحالي', 'التحق', '52', 'ألف', 'تلميذ', 'المدارس', 'الخصوصية', 'بالمدارس', 'العمومية', 'أتيحت', 'الفرصة', 'ستحول', 'ابنك', 'المدرسة', 'الخصوصية', 'العمومية']
#
#  ------------ Stemming : stem
#  ['دافع', 'وزير', 'التربية', 'الوطنية', 'والتكوين', 'المهني', 'والتعليم', 'العالي', 'والبحث', 'العلمي', 'سعيد', 'أمزازي', 'جودة', 'المدرسة', 'العمومية', 'كاشفا', 'أنه', 'خلال', 'الموسم', 'الدراسي', 'الحالي', 'التحق', '52', 'ألف', 'تلميذ', 'المدارس', 'الخصوصية', 'بالمدارس', 'العمومية', 'أتيحت', 'الفرصة', 'ستحول', 'ابنك', 'المدرسة', 'الخصوصية', 'العمومية']
# =================================
# "مؤتمر قومي عربي" في طنجة يشعل الخصام بين يساريين وأمازيغيين
#
# -------------- Tokenzer :
#  : ['مؤتمر', 'قومي', 'عربي', 'في', 'طنجة', 'يشعل', 'الخصام', 'بين', 'يساريين', 'وأمازيغيين']
#
#  ------------ stop word removal : tokens_clean
#  ['مؤتمر', 'قومي', 'عربي', 'طنجة', 'يشعل', 'الخصام', 'يساريين', 'وأمازيغيين']
#
#  ------------ Stemming : stem
#  ['مؤتمر', 'قومي', 'عربي', 'طنجة', 'يشعل', 'الخصام', 'يساريين', 'وأمازيغيين']
# =================================
# مظاهرات واشتباكات مع الشرطة في إسبانيا احتجاجاً على الأحكام ضد قادة انفصال كتالونيا
#
# -------------- Tokenzer :
#  : ['مظاهرات', 'واشتباكات', 'مع', 'الشرطة', 'في', 'إسبانيا', 'احتجاجا', 'على', 'الأحكام', 'ضد', 'قادة', 'انفصال', 'كتالونيا']
#
#  ------------ stop word removal : tokens_clean
#  ['مظاهرات', 'واشتباكات', 'الشرطة', 'إسبانيا', 'احتجاجا', 'الأحكام', 'ضد', 'قادة', 'انفصال', 'كتالونيا']
#
#  ------------ Stemming : stem
#  ['مظاهرات', 'واشتباكات', 'الشرطة', 'إسبانيا', 'احتجاجا', 'الأحكام', 'ضد', 'قادة', 'انفصال', 'كتالونيا']
# =================================
# دفاع "أسود الأطلس" يتعزز بخدمات سايس أمام المنتخب الموريتاني
#
# -------------- Tokenzer :
#  : ['دفاع', 'أسود', 'الأطلس', 'يتعزز', 'بخدمات', 'سايس', 'أمام', 'المنتخب', 'الموريتاني']
#
#  ------------ stop word removal : tokens_clean
#  ['دفاع', 'أسود', 'الأطلس', 'يتعزز', 'بخدمات', 'سايس', 'أمام', 'المنتخب', 'الموريتاني']
#
#  ------------ Stemming : stem
#  ['دفاع', 'أسود', 'الأطلس', 'يتعزز', 'بخدمات', 'سايس', 'أمام', 'المنتخب', 'الموريتاني']
# =================================
# خطاب الملك محمد السادس يخرج مقاولين شبابا إلى الاحتجاج ضد برامج الحكومة
#
# -------------- Tokenzer :
#  : ['خطاب', 'الملك', 'محمد', 'السادس', 'يخرج', 'مقاولين', 'شبابا', 'إلى', 'الاحتجاج', 'ضد', 'برامج', 'الحكومة']
#
#  ------------ stop word removal : tokens_clean
#  ['خطاب', 'الملك', 'محمد', 'السادس', 'يخرج', 'مقاولين', 'شبابا', 'الاحتجاج', 'ضد', 'برامج', 'الحكومة']
#
#  ------------ Stemming : stem
#  ['خطاب', 'الملك', 'محمد', 'السادس', 'يخرج', 'مقاولين', 'شبابا', 'الاحتجاج', 'ضد', 'برامج', 'الحكومة']
# =================================
# حاملين العلم المغربي.. ساكنة جماعة تغجيجت تحتج وتنتفض في وجه "مافيا العقار"
#
# -------------- Tokenzer :
#  : ['حاملين', 'العلم', 'المغربي', 'ساكنة', 'جماعة', 'تغجيجت', 'تحتج', 'وتنتفض', 'في', 'وجه', 'مافيا', 'العقار']
#
#  ------------ stop word removal : tokens_clean
#  ['حاملين', 'العلم', 'المغربي', 'ساكنة', 'جماعة', 'تغجيجت', 'تحتج', 'وتنتفض', 'وجه', 'مافيا', 'العقار']
#
#  ------------ Stemming : stem
#  ['حاملين', 'العلم', 'المغربي', 'ساكنة', 'جماعة', 'تغجيجت', 'تحتج', 'وتنتفض', 'وجه', 'مافيا', 'العقار']
# =================================
# غضب "متعاقدين" ينطلق بإضراب وطني ومقاطعة الامتحان المهني
#
# -------------- Tokenzer :
#  : ['غضب', 'متعاقدين', 'ينطلق', 'بإضراب', 'وطني', 'ومقاطعة', 'الامتحان', 'المهني']
#
#  ------------ stop word removal : tokens_clean
#  ['غضب', 'متعاقدين', 'ينطلق', 'بإضراب', 'وطني', 'ومقاطعة', 'الامتحان', 'المهني']
#
#  ------------ Stemming : stem
#  ['غضب', 'متعاقدين', 'ينطلق', 'بإضراب', 'وطني', 'ومقاطعة', 'الامتحان', 'المهني']
# =================================
# السجائر الإلكترونية تواجه أزمة عالمية بشأن مخاطر صحية محتملة
#
# -------------- Tokenzer :
#  : ['السجائر', 'الإلكترونية', 'تواجه', 'أزمة', 'عالمية', 'بشأن', 'مخاطر', 'صحية', 'محتملة']
#
#  ------------ stop word removal : tokens_clean
#  ['السجائر', 'الإلكترونية', 'تواجه', 'أزمة', 'عالمية', 'بشأن', 'مخاطر', 'صحية', 'محتملة']
#
#  ------------ Stemming : stem
#  ['السجائر', 'الإلكترونية', 'تواجه', 'أزمة', 'عالمية', 'بشأن', 'مخاطر', 'صحية', 'محتملة']
# =================================
# دراسة علمية: الفقر والبطالة يلازمان متوسط العمر المنخفض
#
# -------------- Tokenzer :
#  : ['دراسة', 'علمية', 'الفقر', 'والبطالة', 'يلازمان', 'متوسط', 'العمر', 'المنخفض']
#
#  ------------ stop word removal : tokens_clean
#  ['دراسة', 'علمية', 'الفقر', 'والبطالة', 'يلازمان', 'متوسط', 'العمر', 'المنخفض']
#
#  ------------ Stemming : stem
#  ['دراسة', 'علمية', 'الفقر', 'والبطالة', 'يلازمان', 'متوسط', 'العمر', 'المنخفض']
# =================================
# العوامل الوراثية قد تسبب العقم!
#
# -------------- Tokenzer :
#  : ['العوامل', 'الوراثية', 'قد', 'تسبب', 'العقم']
#
#  ------------ stop word removal : tokens_clean
#  ['العوامل', 'الوراثية', 'تسبب', 'العقم']
#
#  ------------ Stemming : stem
#  ['العوامل', 'الوراثية', 'تسبب', 'العقم']
# =================================
# تحذيرات ترافق زيادة وزن النساء أثناء فترة الحمل
#
# -------------- Tokenzer :
#  : ['تحذيرات', 'ترافق', 'زيادة', 'وزن', 'النساء', 'أثناء', 'فترة', 'الحمل']
#
#  ------------ stop word removal : tokens_clean
#  ['تحذيرات', 'ترافق', 'زيادة', 'وزن', 'النساء', 'أثناء', 'فترة', 'الحمل']
#
#  ------------ Stemming : stem
#  ['تحذيرات', 'ترافق', 'زيادة', 'وزن', 'النساء', 'أثناء', 'فترة', 'الحمل']
# =================================
# لماذا تعدّ هولندا جنة الدراجات الهوائية؟
#
# -------------- Tokenzer :
#  : ['لماذا', 'تعد', 'هولندا', 'جنة', 'الدراجات', 'الهوائية']
#
#  ------------ stop word removal : tokens_clean
#  ['لماذا', 'تعد', 'هولندا', 'جنة', 'الدراجات', 'الهوائية']
#
#  ------------ Stemming : stem
#  ['لماذا', 'تعد', 'هولندا', 'جنة', 'الدراجات', 'الهوائية']
# =================================
# بينما 800 مليون شخص في العالم يعانون من الجوع.. 14 % من الأغذية المنتجة في العالم تتعرض للتلف
#
# -------------- Tokenzer :
#  : ['بينما', '800', 'مليون', 'شخص', 'في', 'العالم', 'يعانون', 'من', 'الجوع', '14', 'من', 'الأغذية', 'المنتجة', 'في', 'العالم', 'تتعرض', 'للتلف']
#
#  ------------ stop word removal : tokens_clean
#  ['بينما', '800', 'مليون', 'شخص', 'العالم', 'يعانون', 'الجوع', '14', 'الأغذية', 'المنتجة', 'العالم', 'تتعرض', 'للتلف']
#
#  ------------ Stemming : stem
#  ['بينما', '800', 'مليون', 'شخص', 'العالم', 'يعانون', 'الجوع', '14', 'الأغذية', 'المنتجة', 'العالم', 'تتعرض', 'للتلف']
# =================================
# نجمة "الكي بوب" الكورية سولي توجد جثة هامدة في شقتها ومعجبوها يغردون بأنها كانت تتعرض للتنمر مما سبب لها الشعور بالوحدة والاكتئاب
#
# -------------- Tokenzer :
#  : ['نجمة', 'الكي', 'بوب', 'الكورية', 'سولي', 'توجد', 'جثة', 'هامدة', 'في', 'شقتها', 'ومعجبوها', 'يغردون', 'بأنها', 'كانت', 'تتعرض', 'للتنمر', 'مما', 'سبب', 'لها', 'الشعور', 'بالوحدة', 'والاكتئاب']
#
#  ------------ stop word removal : tokens_clean
#  ['نجمة', 'الكي', 'بوب', 'الكورية', 'سولي', 'توجد', 'جثة', 'هامدة', 'شقتها', 'ومعجبوها', 'يغردون', 'بأنها', 'كانت', 'تتعرض', 'للتنمر', 'سبب', 'الشعور', 'بالوحدة', 'والاكتئاب']
#
#  ------------ Stemming : stem
#  ['نجمة', 'الكي', 'بوب', 'الكورية', 'سولي', 'توجد', 'جثة', 'هامدة', 'شقتها', 'ومعجبوها', 'يغردون', 'بأنها', 'كانت', 'تتعرض', 'للتنمر', 'سبب', 'الشعور', 'بالوحدة', 'والاكتئاب']
# =================================
# فاطمة الزهراء أخيار تلميذة مغربية من مدينة تطوان تتألق في "برنامج تحدي القراءة العربي" وتتأهل إلى الحلقة الرابعة التي ستشهد تصفيات للمراحل النهائية
#
# -------------- Tokenzer :
#  : ['فاطمة', 'الزهراء', 'أخيار', 'تلميذة', 'مغربية', 'من', 'مدينة', 'تطوان', 'تتألق', 'في', 'برنامج', 'تحدي', 'القراءة', 'العربي', 'وتتأهل', 'إلى', 'الحلقة', 'الرابعة', 'التي', 'ستشهد', 'تصفيات', 'للمراحل', 'النهائية']
#
#  ------------ stop word removal : tokens_clean
#  ['فاطمة', 'الزهراء', 'أخيار', 'تلميذة', 'مغربية', 'مدينة', 'تطوان', 'تتألق', 'برنامج', 'تحدي', 'القراءة', 'العربي', 'وتتأهل', 'الحلقة', 'الرابعة', 'ستشهد', 'تصفيات', 'للمراحل', 'النهائية']
#
#  ------------ Stemming : stem
#  ['فاطمة', 'الزهراء', 'أخيار', 'تلميذة', 'مغربية', 'مدينة', 'تطوان', 'تتألق', 'برنامج', 'تحدي', 'القراءة', 'العربي', 'وتتأهل', 'الحلقة', 'الرابعة', 'ستشهد', 'تصفيات', 'للمراحل', 'النهائية']
# =================================
# المنتخب الجزائري يهزم نظيره الكولومبي ودياً بثلاثية
#
# -------------- Tokenzer :
#  : ['المنتخب', 'الجزائري', 'يهزم', 'نظيره', 'الكولومبي', 'وديا', 'بثلاثية']
#
#  ------------ stop word removal : tokens_clean
#  ['المنتخب', 'الجزائري', 'يهزم', 'نظيره', 'الكولومبي', 'وديا', 'بثلاثية']
#
#  ------------ Stemming : stem
#  ['المنتخب', 'الجزائري', 'يهزم', 'نظيره', 'الكولومبي', 'وديا', 'بثلاثية']
# =================================
# مشتكية ببوعشرين تحاول الانتحار .. وصحافيو "أخبار اليوم" يعتصمون بمقرّ الجريدة
#
# -------------- Tokenzer :
#  : ['مشتكية', 'ببوعشرين', 'تحاول', 'الانتحار', 'وصحافيو', 'أخبار', 'اليوم', 'يعتصمون', 'بمقر', 'الجريدة']
#
#  ------------ stop word removal : tokens_clean
#  ['مشتكية', 'ببوعشرين', 'تحاول', 'الانتحار', 'وصحافيو', 'أخبار', 'اليوم', 'يعتصمون', 'بمقر', 'الجريدة']
#
#  ------------ Stemming : stem
#  ['مشتكية', 'ببوعشرين', 'تحاول', 'الانتحار', 'وصحافيو', 'أخبار', 'اليوم', 'يعتصمون', 'بمقر', 'الجريدة']
# =================================
# المنتخب المغربي يسقط بثلاثية أمام "فهود الغابون" في "وديّة طنجة"
#
# -------------- Tokenzer :
#  : ['المنتخب', 'المغربي', 'يسقط', 'بثلاثية', 'أمام', 'فهود', 'الغابون', 'في', 'ودي', 'ة', 'طنجة']
#
#  ------------ stop word removal : tokens_clean
#  ['المنتخب', 'المغربي', 'يسقط', 'بثلاثية', 'أمام', 'فهود', 'الغابون', 'ودي', 'ة', 'طنجة']
#
#  ------------ Stemming : stem
#  ['المنتخب', 'المغربي', 'يسقط', 'بثلاثية', 'أمام', 'فهود', 'الغابون', 'ودي', 'ة', 'طنجة']
# =================================
# "الناس يهولون ويضخمون مرض السرطان لكنه أمر عاد وعلى الإنسان أن يعيش بشكل طبيعي".. هكذا تسرد لطيفة امرأة تغلبت على السرطان وخضعت لعملية استئصال الثدي قصتها مع المرض
#
# -------------- Tokenzer :
#  : ['الناس', 'يهولون', 'ويضخمون', 'مرض', 'السرطان', 'لكنه', 'أمر', 'عاد', 'وعلى', 'الإنسان', 'أن', 'يعيش', 'بشكل', 'طبيعي', 'هكذا', 'تسرد', 'لطيفة', 'امرأة', 'تغلبت', 'على', 'السرطان', 'وخضعت', 'لعملية', 'استئصال', 'الثدي', 'قصتها', 'مع', 'المرض']
#
#  ------------ stop word removal : tokens_clean
#  ['الناس', 'يهولون', 'ويضخمون', 'مرض', 'السرطان', 'لكنه', 'أمر', 'عاد', 'وعلى', 'الإنسان', 'يعيش', 'بشكل', 'طبيعي', 'تسرد', 'لطيفة', 'امرأة', 'تغلبت', 'السرطان', 'وخضعت', 'لعملية', 'استئصال', 'الثدي', 'قصتها', 'المرض']
#
#  ------------ Stemming : stem
#  ['الناس', 'يهولون', 'ويضخمون', 'مرض', 'السرطان', 'لكنه', 'أمر', 'عاد', 'وعلى', 'الإنسان', 'يعيش', 'بشكل', 'طبيعي', 'تسرد', 'لطيفة', 'امرأة', 'تغلبت', 'السرطان', 'وخضعت', 'لعملية', 'استئصال', 'الثدي', 'قصتها', 'المرض']
# =================================
# نهاية اللقاء الودي بين المنتخب المغربي ونظيره الغابوني بفوز الغابون بثلاثة أهداف لهدفين..
# كيف تقيم أداء المنتخب في هذه المباراة؟
#
# -------------- Tokenzer :
#  : ['نهاية', 'اللقاء', 'الودي', 'بين', 'المنتخب', 'المغربي', 'ونظيره', 'الغابوني', 'بفوز', 'الغابون', 'بثلاثة', 'أهداف', 'لهدفين', 'كيف', 'تقيم', 'أداء', 'المنتخب', 'في', 'هذه', 'المباراة']
#
#  ------------ stop word removal : tokens_clean
#  ['نهاية', 'اللقاء', 'الودي', 'المنتخب', 'المغربي', 'ونظيره', 'الغابوني', 'بفوز', 'الغابون', 'بثلاثة', 'أهداف', 'لهدفين', 'تقيم', 'أداء', 'المنتخب', 'المباراة']
#
#  ------------ Stemming : stem
#  ['نهاية', 'اللقاء', 'الودي', 'المنتخب', 'المغربي', 'ونظيره', 'الغابوني', 'بفوز', 'الغابون', 'بثلاثة', 'أهداف', 'لهدفين', 'تقيم', 'أداء', 'المنتخب', 'المباراة']
# =================================
# في المغرب %93 من النساء القرويات يساهمن في الأنشطة الزراعية وشبه الزراعية بينما تتنوع معاناتهن بين غياب الحقوق الأساسية في التعليم والصحة والعنف الجسدي والنفسي والاجتماعي.. شاركنا بكلمة في حقهن!
#
# -------------- Tokenzer :
#  : ['في', 'المغرب', '93', 'من', 'النساء', 'القرويات', 'يساهمن', 'في', 'الأنشطة', 'الزراعية', 'وشبه', 'الزراعية', 'بينما', 'تتنوع', 'معاناتهن', 'بين', 'غياب', 'الحقوق', 'الأساسية', 'في', 'التعليم', 'والصحة', 'والعنف', 'الجسدي', 'والنفسي', 'والاجتماعي', 'شاركنا', 'بكلمة', 'في', 'حقهن']
#
#  ------------ stop word removal : tokens_clean
#  ['المغرب', '93', 'النساء', 'القرويات', 'يساهمن', 'الأنشطة', 'الزراعية', 'وشبه', 'الزراعية', 'بينما', 'تتنوع', 'معاناتهن', 'غياب', 'الحقوق', 'الأساسية', 'التعليم', 'والصحة', 'والعنف', 'الجسدي', 'والنفسي', 'والاجتماعي', 'شاركنا', 'بكلمة', 'حقهن']
#
#  ------------ Stemming : stem
#  ['المغرب', '93', 'النساء', 'القرويات', 'يساهمن', 'الأنشطة', 'الزراعية', 'وشبه', 'الزراعية', 'بينما', 'تتنوع', 'معاناتهن', 'غياب', 'الحقوق', 'الأساسية', 'التعليم', 'والصحة', 'والعنف', 'الجسدي', 'والنفسي', 'والاجتماعي', 'شاركنا', 'بكلمة', 'حقهن']
# =================================
# 52 ألف تلميذ في المدارس الخصوصية يلتحقون بالتعليم العمومي
#
# -------------- Tokenzer :
#  : ['52', 'ألف', 'تلميذ', 'في', 'المدارس', 'الخصوصية', 'يلتحقون', 'بالتعليم', 'العمومي']
#
#  ------------ stop word removal : tokens_clean
#  ['52', 'ألف', 'تلميذ', 'المدارس', 'الخصوصية', 'يلتحقون', 'بالتعليم', 'العمومي']
#
#  ------------ Stemming : stem
#  ['52', 'ألف', 'تلميذ', 'المدارس', 'الخصوصية', 'يلتحقون', 'بالتعليم', 'العمومي']
# =================================
# على ضفاف نهر أبي رقراق نُسجت حكاية "جمهورية قراصنة سلا" التي دافعت على أمن شمال أفريقيا وأرعبت أوروبا وتاجرت في مواطنيها انتقاما للدين والتاريخ قبل إضعافها والإعلان عن سقوطها.
#
# -------------- Tokenzer :
#  : ['على', 'ضفاف', 'نهر', 'أبي', 'رقراق', 'ن', 'سجت', 'حكاية', 'جمهورية', 'قراصنة', 'سلا', 'التي', 'دافعت', 'على', 'أمن', 'شمال', 'أفريقيا', 'وأرعبت', 'أوروبا', 'وتاجرت', 'في', 'مواطنيها', 'انتقاما', 'للدين', 'والتاريخ', 'قبل', 'إضعافها', 'والإعلان', 'عن', 'سقوطها']
#
#  ------------ stop word removal : tokens_clean
#  ['ضفاف', 'نهر', 'أبي', 'رقراق', 'ن', 'سجت', 'حكاية', 'جمهورية', 'قراصنة', 'سلا', 'دافعت', 'أمن', 'شمال', 'أفريقيا', 'وأرعبت', 'أوروبا', 'وتاجرت', 'مواطنيها', 'انتقاما', 'للدين', 'والتاريخ', 'قبل', 'إضعافها', 'والإعلان', 'سقوطها']
#
#  ------------ Stemming : stem
#  ['ضفاف', 'نهر', 'أبي', 'رقراق', 'ن', 'سجت', 'حكاية', 'جمهورية', 'قراصنة', 'سلا', 'دافعت', 'أمن', 'شمال', 'أفريقيا', 'وأرعبت', 'أوروبا', 'وتاجرت', 'مواطنيها', 'انتقاما', 'للدين', 'والتاريخ', 'قبل', 'إضعافها', 'والإعلان', 'سقوطها']
# =================================
# صور .. عارضة ومغنية أمريكية تستعرض مفاتن حملها في باحات مسجد الحسن الثاني
#
# -------------- Tokenzer :
#  : ['صور', 'عارضة', 'ومغنية', 'أمريكية', 'تستعرض', 'مفاتن', 'حملها', 'في', 'باحات', 'مسجد', 'الحسن', 'الثاني']
#
#  ------------ stop word removal : tokens_clean
#  ['صور', 'عارضة', 'ومغنية', 'أمريكية', 'تستعرض', 'مفاتن', 'حملها', 'باحات', 'مسجد', 'الحسن', 'الثاني']
#
#  ------------ Stemming : stem
#  ['صور', 'عارضة', 'ومغنية', 'أمريكية', 'تستعرض', 'مفاتن', 'حملها', 'باحات', 'مسجد', 'الحسن', 'الثاني']
# =================================
# "خرجت لحانوت نتقدا جيت لقيت الدري مات".. أم ترثي ابنها ضحية "شارجور" في البيضاء
#
# -------------- Tokenzer :
#  : ['خرجت', 'لحانوت', 'نتقدا', 'جيت', 'لقيت', 'الدري', 'مات', 'أم', 'ترثي', 'ابنها', 'ضحية', 'شارجور', 'في', 'البيضاء']
#
#  ------------ stop word removal : tokens_clean
#  ['خرجت', 'لحانوت', 'نتقدا', 'جيت', 'لقيت', 'الدري', 'مات', 'ترثي', 'ابنها', 'ضحية', 'شارجور', 'البيضاء']
#
#  ------------ Stemming : stem
#  ['خرجت', 'لحانوت', 'نتقدا', 'جيت', 'لقيت', 'الدري', 'مات', 'ترثي', 'ابنها', 'ضحية', 'شارجور', 'البيضاء']
# =================================
# وزارة الداخلية تدعو إلى تمكين الأطفال المزدادين خارج مؤسسة الزواج من التسجيل في دفتر الحالة المدنية.. ما رأيك في هذه الخطوة؟
#
# -------------- Tokenzer :
#  : ['وزارة', 'الداخلية', 'تدعو', 'إلى', 'تمكين', 'الأطفال', 'المزدادين', 'خارج', 'مؤسسة', 'الزواج', 'من', 'التسجيل', 'في', 'دفتر', 'الحالة', 'المدنية', 'ما', 'رأيك', 'في', 'هذه', 'الخطوة']
#
#  ------------ stop word removal : tokens_clean
#  ['وزارة', 'الداخلية', 'تدعو', 'تمكين', 'الأطفال', 'المزدادين', 'خارج', 'مؤسسة', 'الزواج', 'التسجيل', 'دفتر', 'الحالة', 'المدنية', 'رأيك', 'الخطوة']
#
#  ------------ Stemming : stem
#  ['وزارة', 'الداخلية', 'تدعو', 'تمكين', 'الأطفال', 'المزدادين', 'خارج', 'مؤسسة', 'الزواج', 'التسجيل', 'دفتر', 'الحالة', 'المدنية', 'رأيك', 'الخطوة']
# =================================
# تفاصيل حادثة انحراف قطار قادم من مراكش صوب الدار البيضاء في منطقة بوسكورة
#
# -------------- Tokenzer :
#  : ['تفاصيل', 'حادثة', 'انحراف', 'قطار', 'قادم', 'من', 'مراكش', 'صوب', 'الدار', 'البيضاء', 'في', 'منطقة', 'بوسكورة']
#
#  ------------ stop word removal : tokens_clean
#  ['تفاصيل', 'حادثة', 'انحراف', 'قطار', 'قادم', 'مراكش', 'صوب', 'الدار', 'البيضاء', 'منطقة', 'بوسكورة']
#
#  ------------ Stemming : stem
#  ['تفاصيل', 'حادثة', 'انحراف', 'قطار', 'قادم', 'مراكش', 'صوب', 'الدار', 'البيضاء', 'منطقة', 'بوسكورة']
# =================================
# مفجع .. "شارجور هاتف" يقتل طفلا ويُخلف خسائر جسيمة في منزل بالدار البيضاء
#
# -------------- Tokenzer :
#  : ['مفجع', 'شارجور', 'هاتف', 'يقتل', 'طفلا', 'وي', 'خلف', 'خسائر', 'جسيمة', 'في', 'منزل', 'بالدار', 'البيضاء']
#
#  ------------ stop word removal : tokens_clean
#  ['مفجع', 'شارجور', 'هاتف', 'يقتل', 'طفلا', 'وي', 'خلف', 'خسائر', 'جسيمة', 'منزل', 'بالدار', 'البيضاء']
#
#  ------------ Stemming : stem
#  ['مفجع', 'شارجور', 'هاتف', 'يقتل', 'طفلا', 'وي', 'خلف', 'خسائر', 'جسيمة', 'منزل', 'بالدار', 'البيضاء']
# =================================
# "العالم تصرخ مستغيثة.. الناس عالقون.. المشهد مبك هنا".. هكذا تصف مراسلة قناةٍ لبنانيةٍ مشهد محاصرة ألسنة اللهب لمنازل لبنانيين وسماعها أصوات صراخ استغاثتهم
#
# -------------- Tokenzer :
#  : ['العالم', 'تصرخ', 'مستغيثة', 'الناس', 'عالقون', 'المشهد', 'مبك', 'هنا', 'هكذا', 'تصف', 'مراسلة', 'قناة', 'لبنانية', 'مشهد', 'محاصرة', 'ألسنة', 'اللهب', 'لمنازل', 'لبنانيين', 'وسماعها', 'أصوات', 'صراخ', 'استغاثتهم']
#
#  ------------ stop word removal : tokens_clean
#  ['العالم', 'تصرخ', 'مستغيثة', 'الناس', 'عالقون', 'المشهد', 'مبك', 'تصف', 'مراسلة', 'قناة', 'لبنانية', 'مشهد', 'محاصرة', 'ألسنة', 'اللهب', 'لمنازل', 'لبنانيين', 'وسماعها', 'أصوات', 'صراخ', 'استغاثتهم']
#
#  ------------ Stemming : stem
#  ['العالم', 'تصرخ', 'مستغيثة', 'الناس', 'عالقون', 'المشهد', 'مبك', 'تصف', 'مراسلة', 'قناة', 'لبنانية', 'مشهد', 'محاصرة', 'ألسنة', 'اللهب', 'لمنازل', 'لبنانيين', 'وسماعها', 'أصوات', 'صراخ', 'استغاثتهم']
# =================================
# بالفيديو .. هكذا انحرف قطار عن سكته في بوسكورة
#
# -------------- Tokenzer :
#  : ['بالفيديو', 'هكذا', 'انحرف', 'قطار', 'عن', 'سكته', 'في', 'بوسكورة']
#
#  ------------ stop word removal : tokens_clean
#  ['بالفيديو', 'انحرف', 'قطار', 'سكته', 'بوسكورة']
#
#  ------------ Stemming : stem
#  ['بالفيديو', 'انحرف', 'قطار', 'سكته', 'بوسكورة']
# =================================

# %%
from collections import Counter
import spacy
nlp = spacy.load('facebook')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-0fd44e00a1d8> in <module>
#       1 from collections import Counter
#       2 import spacy
# ----> 3 nlp = spacy.load('en_core_web_md')
#
# ~\Anaconda3\lib\site-packages\spacy\__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# ~\Anaconda3\lib\site-packages\spacy\util.py in load_model(name, **overrides)
#     169     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     170         return load_model_from_path(name, **overrides)
# --> 171     raise IOError(Errors.E050.format(name=name))
#     172
#     173
#
# OSError: [E050] Can't find model 'en_core_web_md'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.
