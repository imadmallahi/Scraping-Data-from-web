# %%
from facebook_scraper import get_posts
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import WordPunctTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords


#RegexpTokensizer class : A RegexplTokenizer
from nltk.tokenize import RegexpTokenizer

stemmer = PorterStemmer()

for post in get_posts('facebook', pages=20):
    print(post['text'])
    if not post['text']:
        print("**")
    else:        
        tokenizer = RegexpTokenizer(r'\w+')#remove also puntion
        
        token  = tokenizer.tokenize(post['text'])
        print("\n-------------- Tokenzer :\n :", token )
        stopwords_en = stopwords.words('english')
        tokens_clean = [t for t in token if  t not in stopwords_en]
        print("\n ------------ stop word removal : tokens_clean \n",tokens_clean)
        #Stemming using PorterStemmer()
        stems =[stemmer.stem(t) for t in tokens_clean]
        print("\n ------------ Stemming : stem  \n",stems)
        # lower max_font_size, change the maximum number of word and lighten the background:
        wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(post['text'])
        plt.figure()
        plt.imshow(wordcloud, interpolation="bilinear")
        plt.axis("off")
        plt.show()
        print('=================================')
# Out:
# There’s nothing like a good monster mash to get everyone together. #MoreHalloween #MoreTogether
#
# -------------- Tokenzer :
#  : ['There', 's', 'nothing', 'like', 'a', 'good', 'monster', 'mash', 'to', 'get', 'everyone', 'together', 'MoreHalloween', 'MoreTogether']
#
#  ------------ stop word removal : tokens_clean
#  ['There', 'nothing', 'like', 'good', 'monster', 'mash', 'get', 'everyone', 'together', 'MoreHalloween', 'MoreTogether']
#
#  ------------ Stemming : stem
#  ['there', 'noth', 'like', 'good', 'monster', 'mash', 'get', 'everyon', 'togeth', 'morehalloween', 'moretogeth']
# ...
# We love watching these old friends stay connected on the new family of Portals. Portal from Facebook you think they would be up for joining a Facebook group, like Puppet Films Group ~?
# No matter where life takes you, feel close to the ones you love with the new family of Portals from Facebook. Pre-order today! https://portalfb.me/30uSIaK
#
# -------------- Tokenzer :
# ...

# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt


text = df.description[0]

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-015e9cafa29f> in <module>
#       8
#       9
# ---> 10 text = df.description[0]
#      11
#      12 # Create and generate a word cloud image:
#
# NameError: name 'df' is not defined
